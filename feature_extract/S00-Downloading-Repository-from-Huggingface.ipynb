# %%
from huggingface_hub import snapshot_download
# Download the repository from Hugging Face
snapshot_download(repo_id="MahmoodLab/TITAN", repo_type="model",cache_dir="/Data/Pathology/checkpoints/", local_dir_use_symlinks=False )
# Out:
# Fetching 20 files:   0%|          | 0/20 [00:00<?, ?it/s]
# README.md:   0%|          | 0.00/9.51k [00:00<?, ?B/s]
# conch_tokenizer.py:   0%|          | 0.00/1.65k [00:00<?, ?B/s]
# .gitattributes:   0%|          | 0.00/1.56k [00:00<?, ?B/s]
# (…).87FE37CE-7A75-4480-BA6B-ED98B7B25D49.h5:   0%|          | 0.00/11.4M [00:00<?, ?B/s]
# (…).C2D3BC09-411F-46CF-811B-FDBA7C2A295B.h5:   0%|          | 0.00/14.3M [00:00<?, ?B/s]
# (…).4E62E4F4-415C-46EB-A6C8-45BA14E82708.h5:   0%|          | 0.00/8.53M [00:00<?, ?B/s]
# TCGA_TITAN_features.pkl:   0%|          | 0.00/36.5M [00:00<?, ?B/s]
# (…).70672250-BF2D-4E3F-8242-3638C0362D2D.h5:   0%|          | 0.00/23.1M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/6.37k [00:00<?, ?B/s]
# conch_v1_5.py:   0%|          | 0.00/26.1k [00:00<?, ?B/s]
# conch_v1_5_pytorch_model.bin:   0%|          | 0.00/1.22G [00:00<?, ?B/s]
# configuration_titan.py:   0%|          | 0.00/4.15k [00:00<?, ?B/s]
# ...
